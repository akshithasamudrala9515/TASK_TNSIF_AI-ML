# %% [markdown]
# <a href="https://colab.research.google.com/github/akshithasamudrala9515/TASK_TNSIF_AI-ML/blob/main/MiniProject_Datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mini Project:**
#
# Create a Student Report Card Program using:
#
# 1.List → store student names
#
# 2.Set → store subjects
#
# 3.Tuple → store student information (name, age)
#
# 4.Dictionary → store subject-wise marks
#
# Requirements:
#
# 1.Ask the user to enter:
#
# *Student name
#
# *Age
#
# *Number of subjects
#
# 2.For each subject:
#
# *Enter subject name
#
# *Enter marks
#
# 3.Store:
#
# *Name in a list
#
# *Subjects in a set
#
# *Student info in a tuple
#
# *Marks in a dictionary
# 4.Print a report card showing:
#
# *Name
#
# *Age
#
# *Subjects
#
# *Marks
#
# *Total marks
#
# *Average marks

# %%
#Student Report Card
students = []

name = input("Enter your name: ")
age = int(input("Enter your age: "))

subjects = set()
num_subjects = int(input("Enter number of subjects: "))

students.append(name)

student_info = (name, age)
marks = {}

for i in range(num_subjects):
    subject = input("Enter subject name: ")
    mark = int(input("Enter marks: "))

    subjects.add(subject)
    marks[subject] = mark

total = sum(marks.values())
avg = total / num_subjects

print("\n****Student Report Card****")
print("Name:", student_info[0])
print("Age:", student_info[1])
print("Subjects:", subjects)

print("Marks:")
for subject, mark in marks.items():
    print(subject, ":", mark)

print("Total Marks:", total)
print("Average Marks:", avg)
# Out:
# Enter your name: akshitha
# Enter your age: 22
# Enter number of subjects: 3
# Enter subject name: maths
# Enter marks: 95
# Enter subject name: science
# Enter marks: 96
# Enter subject name: social
# Enter marks: 97
#
# ****Student Report Card****
# Name: akshitha
# Age: 22
# Subjects: {'social', 'maths', 'science'}
# Marks:
# maths : 95
# science : 96
# social : 97
# Total Marks: 288
# Average Marks: 96.0
