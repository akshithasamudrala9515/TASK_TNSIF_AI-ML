# %% [markdown]
# <a href="https://colab.research.google.com/github/akshithasamudrala9515/TASK_TNSIF_AI-ML/blob/main/Miniproject_Module1(youtubeanalytics).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-613d343b-d0cd-4091-8762-128f6476f93d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-613d343b-d0cd-4091-8762-128f6476f93d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
print(os.listdir())
# Out:
# ['.config', 'drive', 'Global_YouTube_Statistics.csv', 'Global YouTube Statistics .csv', '.ipynb_checkpoints', 'sample_data']

# %%
yt = pd.read_csv('/content/Global YouTube Statistics .csv', encoding='latin1')

# %%
yt.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
yt.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
yt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
top_subscribers = yt[['Youtuber', 'subscribers']]\
                    .sort_values(by='subscribers', ascending=False)

print(top_subscribers.head(10))
# Out:
#                      Youtuber  subscribers
# 0                    T-Series    245000000
# 1              YouTube Movies    170000000
# 2                     MrBeast    166000000
# 3  Cocomelon - Nursery Rhymes    162000000
# 4                   SET India    159000000
# 5                       Music    119000000
# 6         ýýý Kids Diana Show    112000000
# 7                   PewDiePie    111000000
# 8                 Like Nastya    106000000
# 9               Vlad and Niki     98900000

# %%
top_views = yt[['Youtuber', 'video views']]\
                .sort_values(by='video views', ascending=False)

print(top_views.head(10))
# Out:
#                       Youtuber   video views
# 0                     T-Series  2.280000e+11
# 3   Cocomelon - Nursery Rhymes  1.640000e+11
# 4                    SET India  1.480000e+11
# 15                    Sony SAB  1.010000e+11
# 6          ýýý Kids Diana Show  9.324704e+10
# 8                  Like Nastya  9.047906e+10
# 11                         WWE  7.742847e+10
# 9                Vlad and Niki  7.718017e+10
# 21                      Zee TV  7.313905e+10
# 26                   Colors TV  6.151091e+10

# %%
top_subscribers = yt.nlargest(10, 'subscribers')

plt.figure(figsize=(10,6))
sns.barplot(x='subscribers', y='Youtuber', data=top_subscribers)

plt.title('Top 10 YouTube Channels by Subscribers')
plt.xlabel('Subscribers')
plt.ylabel('YouTube Channel')

plt.show()

# %%
top_views= yt.nlargest(10,'video views')
plt.figure(figsize=(10,6))
sns.barplot(x='video views',y='Youtuber',data=top_views)
plt.title('Top 10 YouTube Channels by Video Views')
plt.xlabel('Video Views')
plt.ylabel('YouTube Channel')
plt.show()

# %%
country_counts = yt['Country'].value_counts()

print(country_counts.head())
# Out:
# Country
# United States     313
# India             168
# Brazil             62
# United Kingdom     43
# Mexico             33
# Name: count, dtype: int64

# %%
top_countries = yt['Country'].value_counts().head(10)

plt.figure(figsize=(10,6))
plt.barh(top_countries.index, top_countries.values)

plt.title('Top 10 Countries by Number of YouTube Creators')
plt.xlabel('Number of Creators')
plt.ylabel('Country')

plt.show()
